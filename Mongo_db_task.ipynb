# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanth1234/DW4--Assignment-2/blob/main/Mongo_db_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow
# !pip install dnspython
# !pip install pymongo[srv]
# Out:
# ...
#      |████████████████████████████████| 266 kB 5.1 MB/s
# ...

# %%
import pymongo
from pymongo import MongoClient
from PIL import Image
import io
from termcolor import colored

# %%
Client = pymongo.MongoClient("mongodb+srv://Shantharam:Schneider05@cluster0.aokml.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = Client.Students
records = db.Dataset

# %%
import json
data = []
for line in open ('/content/students.json','r'):
  data.append(json.loads(line))

# %%
for i in range (len(data)):
  records.insert_one(data[i])

# %%
count=0
for x in records.find():
  count+=1
  print("Total number of students documents uploaded in data base",count)
# Out:
# Total number of students documents uploaded in data base 1
# Total number of students documents uploaded in data base 2
# Total number of students documents uploaded in data base 3
# Total number of students documents uploaded in data base 4
# Total number of students documents uploaded in data base 5
# Total number of students documents uploaded in data base 6
# Total number of students documents uploaded in data base 7
# Total number of students documents uploaded in data base 8
# Total number of students documents uploaded in data base 9
# Total number of students documents uploaded in data base 10
# Total number of students documents uploaded in data base 11
# Total number of students documents uploaded in data base 12
# Total number of students documents uploaded in data base 13
# Total number of students documents uploaded in data base 14
# Total number of students documents uploaded in data base 15
# Total number of students documents uploaded in data base 16
# ...

# %% [markdown]
# 1 Q

# %%
for x in records.find({'scores.type':'exam'},{'scores.score':1}):
  print(x)
# Out:
# {'_id': 0, 'scores': [{'score': 1.463179736705023}, {'score': 11.78273309957772}, {'score': 35.8740349954354}]}
# {'_id': 1, 'scores': [{'score': 60.06045071030959}, {'score': 52.79790691903873}, {'score': 71.76133439165544}]}
# {'_id': 2, 'scores': [{'score': 67.03077096065002}, {'score': 6.301851677835235}, {'score': 66.28344683278382}]}
# {'_id': 3, 'scores': [{'score': 71.64343899778332}, {'score': 24.80221293650313}, {'score': 42.26147058804812}]}
# {'_id': 4, 'scores': [{'score': 78.68385091304332}, {'score': 90.2963101368042}, {'score': 34.41620148042529}]}
# {'_id': 5, 'scores': [{'score': 44.87186330181261}, {'score': 25.72395114668016}, {'score': 63.42288310628662}]}
# {'_id': 6, 'scores': [{'score': 37.32285459166097}, {'score': 28.32634976913737}, {'score': 81.57115318686338}]}
# {'_id': 7, 'scores': [{'score': 90.37826509157176}, {'score': 42.48780666956811}, {'score': 96.52986171633331}]}
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-987d659fb89e> in <module>()
#       1 query= {"scores":[1]}
# ----> 2 mydoc=records.find(query,{"_id":0})
#       3
#       4 for x in mydoc:
#       5   print(x)
#
# TypeError: slice indices must be integers or None or have an __index__ method
